# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
article = pd.read_csv('articles.csv',low_memory=False)
topic_names = pd.read_csv('articleTopicNames.csv')
news_read = pd.read_csv('news_read.csv')
user_topic = pd.read_csv('user_topic_subscriptions.csv')
articles_read = pd.read_csv('user_articles_read.csv')

# %%
article.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21855 entries, 0 to 21854
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                21855 non-null  int64
#  1   language          21855 non-null  int64
#  2   title             21833 non-null  object
#  3   cardTitle         1019 non-null   object
#  4   writtenTitle      20772 non-null  object
#  5   slug              20745 non-null  object
#  6   summary           20537 non-null  object
#  7   writtenSummary    20454 non-null  object
#  8   fullText          4036 non-null   object
#  9   newsType          1914 non-null   float64
#  10  link              21767 non-null  object
#  11  videoID           373 non-null    object
#  12  source            20502 non-null  object
#  13  trending          21855 non-null  int64
#  14  editorPick        21855 non-null  int64
#  15  sendNotification  21855 non-null  int64
# ...

# %%
article.contentStyleID.isnull().sum()
# Out:
# 21467

# %%
articles = article[['id','title','keywords','summary','publishedOn']].copy()

# %%
articles.head()
# Out:
#    id                                              title  \
# 0  12  Spain will reopen borders to EU states on June...
# 1  13  Spanish judge shelves case against Women’s Day...
# 2  14  Spain edges closer to ‘new normality’ with fin...
# 3  15  EU’s call to open internal borders by June 15 ...
# 4  16  Spain prepares for next phase change of corona...
#
#                                 keywords  \
# 0                    border,spain,travel
# 1     women's day,spanish judge,covid-19
# 2          final phase,coronavirus,SPAIN
# 3     internal borders,spain,coronavirus
# 4  new normality,deescalation plan,spain
#
#                                              summary          publishedOn
# 0  During his weekly video conference with Spain’...  2020-06-15 05:29:12
# 1  A Madrid judge announced on Friday that she is...  2020-06-15 08:53:15
# 2  The northwestern region of Galicia is moving f...  2020-06-15 09:01:40
# ...

# %%
topic_names.head()
# Out:
#                                   topicNames  articleID
# 0                  Coronavirus,Europe,Travel         12
# 1  Coronavirus,Global health,Gender Equality         13
# 2         Coronavirus,Politics,Global health         14
# 3                Coronavirus,Politics,Europe         15
# 4         Coronavirus,Politics,Global health         16

# %%
topic_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21658 entries, 0 to 21657
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   topicNames  21658 non-null  object
#  1   articleID   21658 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 338.5+ KB

# %%
topic_names = topic_names.rename({'articleID':'id'},axis=1)

# %%
topic_names.head()
# Out:
#                                   topicNames  id
# 0                  Coronavirus,Europe,Travel  12
# 1  Coronavirus,Global health,Gender Equality  13
# 2         Coronavirus,Politics,Global health  14
# 3                Coronavirus,Politics,Europe  15
# 4         Coronavirus,Politics,Global health  16

# %%
main1 = pd.merge(articles,topic_names)

# %%
main1.head()
# Out:
#    id                                              title  \
# 0  12  Spain will reopen borders to EU states on June...
# 1  13  Spanish judge shelves case against Women’s Day...
# 2  14  Spain edges closer to ‘new normality’ with fin...
# 3  15  EU’s call to open internal borders by June 15 ...
# 4  16  Spain prepares for next phase change of corona...
#
#                                 keywords  \
# 0                    border,spain,travel
# 1     women's day,spanish judge,covid-19
# 2          final phase,coronavirus,SPAIN
# 3     internal borders,spain,coronavirus
# 4  new normality,deescalation plan,spain
#
#                                              summary          publishedOn  \
# 0  During his weekly video conference with Spain’...  2020-06-15 05:29:12
# 1  A Madrid judge announced on Friday that she is...  2020-06-15 08:53:15
# 2  The northwestern region of Galicia is moving f...  2020-06-15 09:01:40
# ...

# %%
main1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21658 entries, 0 to 21657
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           21658 non-null  int64
#  1   title        21656 non-null  object
#  2   keywords     2465 non-null   object
#  3   summary      20440 non-null  object
#  4   publishedOn  19338 non-null  object
#  5   topicNames   21658 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.2+ MB

# %%
main2 = main1.rename({'id':'newsID'},axis=1)

# %%
main2.head()
# Out:
#    newsID                                              title  \
# 0      12  Spain will reopen borders to EU states on June...
# 1      13  Spanish judge shelves case against Women’s Day...
# 2      14  Spain edges closer to ‘new normality’ with fin...
# 3      15  EU’s call to open internal borders by June 15 ...
# 4      16  Spain prepares for next phase change of corona...
#
#                                 keywords  \
# 0                    border,spain,travel
# 1     women's day,spanish judge,covid-19
# 2          final phase,coronavirus,SPAIN
# 3     internal borders,spain,coronavirus
# 4  new normality,deescalation plan,spain
#
#                                              summary          publishedOn  \
# 0  During his weekly video conference with Spain’...  2020-06-15 05:29:12
# 1  A Madrid judge announced on Friday that she is...  2020-06-15 08:53:15
# 2  The northwestern region of Galicia is moving f...  2020-06-15 09:01:40
# ...

# %%
news_read.head(1)
# Out:
#    newsID                           uid  watchTimeInSeconds  \
# 0       1  2EHvElPRM3MckdZaMRP3a2fMLfi2                   3
#
#     newsViewedDateTime  isShared  isBookmarked  isReadInDetails  \
# 0  2020-09-09 22:16:15         0             0                0
#
#              createdAt            updatedAt
# 0  2020-09-25 14:31:10  2020-09-25 14:31:10

# %%
news_read_main = news_read[['newsID','uid','watchTimeInSeconds']].copy()

# %%
news_read_main.head()
# Out:
#    newsID                           uid  watchTimeInSeconds
# 0       1  2EHvElPRM3MckdZaMRP3a2fMLfi2                   3
# 1       1  luNCbENhOUNXUE8FYi3ejFxQSNK2                   1
# 2       1  TzNre0ocC7PcDLUrHFDlwjorYcW2                   1
# 3       2  2EHvElPRM3MckdZaMRP3a2fMLfi2                   1
# 4       2  luNCbENhOUNXUE8FYi3ejFxQSNK2                   1

# %%
news_read_main.tail()
# Out:
#         newsID                           uid  watchTimeInSeconds
# 818435   23161  DgSm71FPEjbPqmosq0GwH1zvQVQ2                   3
# 818436   23162  DgSm71FPEjbPqmosq0GwH1zvQVQ2                   4
# 818437   23166  DgSm71FPEjbPqmosq0GwH1zvQVQ2                   2
# 818438   23167  BEIyAJzzgIb1AK8vGIUUagA3n3z1                   0
# 818439   23168  DgSm71FPEjbPqmosq0GwH1zvQVQ2                   3

# %%
news_read_main.nunique()
# Out:
# newsID                18300
# uid                    8424
# watchTimeInSeconds     1374
# dtype: int64

# %%
user2 = pd.merge(news_read_main,main2)

# %%
user2.head()
# Out:
#    newsID                           uid  watchTimeInSeconds  \
# 0      12                           NaN                   3
# 1      12  0bCevN2VYjP8xtFOWzL2PhSrRhF3                   1
# 2      12  0BqUU9G19RT1nWbqDVrftCzMNSz2                   2
# 3      12  0Di4XsfDVOZThME82IbBie1qhGy2                   2
# 4      12  0HUp1SizlSXHXA4v1JJ8PtuJcOH2                   1
#
#                                                title             keywords  \
# 0  Spain will reopen borders to EU states on June...  border,spain,travel
# 1  Spain will reopen borders to EU states on June...  border,spain,travel
# 2  Spain will reopen borders to EU states on June...  border,spain,travel
# 3  Spain will reopen borders to EU states on June...  border,spain,travel
# 4  Spain will reopen borders to EU states on June...  border,spain,travel
#
#                                              summary          publishedOn  \
# 0  During his weekly video conference with Spain’...  2020-06-15 05:29:12
# ...

# %%
user2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 818401 entries, 0 to 818400
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   newsID              818401 non-null  int64
#  1   uid                 806410 non-null  object
#  2   watchTimeInSeconds  818401 non-null  int64
#  3   title               818401 non-null  object
#  4   keywords            9368 non-null    object
#  5   summary             651017 non-null  object
#  6   publishedOn         817965 non-null  object
#  7   topicNames          818401 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 56.2+ MB

# %%
user2.watchTimeInSeconds.dropna()
# Out:
# 0         3
# 1         1
# 2         2
# 3         2
# 4         1
#          ..
# 818396    3
# 818397    4
# 818398    2
# 818399    0
# 818400    3
# Name: watchTimeInSeconds, Length: 818401, dtype: int64

# %%
user2.tail(2)
# Out:
#         newsID                           uid  watchTimeInSeconds  \
# 818399   23167  BEIyAJzzgIb1AK8vGIUUagA3n3z1                   0
# 818400   23168  DgSm71FPEjbPqmosq0GwH1zvQVQ2                   3
#
#                                                     title keywords  \
# 818399       IMF: UK economy to grow faster than expected      NaN
# 818400  Tech giants' profits soar as demand for cloud ...      NaN
#
#                                                   summary  \
# 818399  The UK economy will grow faster than expected ...
# 818400  Tech giants reported soaring profits as consum...
#
#                 publishedOn                      topicNames
# 818399  2021-07-28 19:47:34  Business,Local News,Happy news
# 818400  2021-07-28 20:02:43  Business,Technology,Happy news

# %%
user2.nunique()
# Out:
# newsID                18290
# uid                    8424
# watchTimeInSeconds     1373
# title                 18084
# keywords                852
# summary               17168
# publishedOn           18140
# topicNames             1341
# dtype: int64

# %%
user1_mat = pd.pivot_table(index='topicNames',columns='uid',values='watchTimeInSeconds',data=user2,aggfunc=np.sum)

# %%
user1_mat
# Out:
# uid                                     04gGwIUvBGVOb8i32tYsaSc4hRx2  \
# topicNames
# Africa                                                           NaN
# Africa,Art and Culture                                           NaN
# Africa,Art and Culture,Conflicts                                 NaN
# Africa,Art and Culture,Happy news                                NaN
# Africa,Art and Culture,Human Rights                              NaN
# ...                                                              ...
# Travel,Latin America,Science                                     NaN
# Travel,Local News                                                1.0
# Travel,Local News,Climate Crisis                                 NaN
# Travel,Local News,Happy news                                     NaN
# Travel,Social Movements,Climate Crisis                           NaN
#
# uid                                     05KsCFRAcbO04jr7l2XZvRK2SaP2  \
# topicNames
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Total time user's spent on the app(posts) by each user

# %%
total_time_spent = pd.DataFrame(user2.groupby('uid')['watchTimeInSeconds'].sum().sort_values(ascending=False))

# %%
total_time_spent.head()
# Out:
#                               watchTimeInSeconds
# uid
# umwq2cxbjiRXMLPNkTmA5p4BjRm2              278823
# pI3mZ48FuHcoPlqnWFHRxm6cSIG3              164057
# do3q2Ct77ybMtmpK39R7PNNnS383              133858
# Z1gKLZlX4IdqzqTcYpuAo8Qwxyz1              129535
# d8LA8SCbBhXjUXahIBVEsYlLg8C3              113395

# %%
total_time_spent['watchTimeInMinutes'] = total_time_spent.watchTimeInSeconds/60
total_time_spent['watchTimeInHours'] = total_time_spent.watchTimeInMinutes/60

# %%
total_time_spent.head()
# Out:
#                               watchTimeInSeconds  watchTimeInMinutes  \
# uid
# umwq2cxbjiRXMLPNkTmA5p4BjRm2              278823         4647.050000
# pI3mZ48FuHcoPlqnWFHRxm6cSIG3              164057         2734.283333
# do3q2Ct77ybMtmpK39R7PNNnS383              133858         2230.966667
# Z1gKLZlX4IdqzqTcYpuAo8Qwxyz1              129535         2158.916667
# d8LA8SCbBhXjUXahIBVEsYlLg8C3              113395         1889.916667
#
#                               watchTimeInHours
# uid
# umwq2cxbjiRXMLPNkTmA5p4BjRm2         77.450833
# pI3mZ48FuHcoPlqnWFHRxm6cSIG3         45.571389
# do3q2Ct77ybMtmpK39R7PNNnS383         37.182778
# Z1gKLZlX4IdqzqTcYpuAo8Qwxyz1         35.981944
# d8LA8SCbBhXjUXahIBVEsYlLg8C3         31.498611

# %%
total_time_spent.loc['umwq2cxbjiRXMLPNkTmA5p4BjRm2']
# Out:
# watchTimeInSeconds    278823.000000
# watchTimeInMinutes      4647.050000
# watchTimeInHours          77.450833
# Name: umwq2cxbjiRXMLPNkTmA5p4BjRm2, dtype: float64

# %%
total_time_spent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8424 entries, umwq2cxbjiRXMLPNkTmA5p4BjRm2 to My6ZBptzUbX3ZMeuUy4lXNaF3jw1
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   watchTimeInSeconds  8424 non-null   int64
#  1   watchTimeInMinutes  8424 non-null   float64
#  2   watchTimeInHours    8424 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 521.3+ KB

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Which topics names are studied mostly by the user's (or) which topic related news articles are mostly studied by the users

# %%
most_popular_topics = pd.DataFrame(user2.groupby('topicNames')['uid'].count().sort_values(ascending=False))

# %%
most_popular_topics.head(20)
# Out:
#                               uid
# topicNames
# Local News                  40870
# Politics,Local News         20414
# Global health,Local News    15671
# Politics,Europe             15223
# Global health               12149
# Politics,North America      11922
# Business,Local News         11183
# Technology                  10094
# Climate Crisis               9997
# Politics,Africa              9520
# Global health,Science        9369
# Politics,Asia                8044
# Local News,Human Rights      7568
# Local News,Happy news        7320
# Politics                     7294
# Business,Europe              7086
# Africa,Human Rights          6997
# Politics,Europe,Local News   6939
# Science                      6717
# Business,Technology          6311

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Total topics covered by each user.....

# %%
k = user2.uid.unique()[1:]

# %%
users_list = list(k)

# %%
total_no_topics = user1_mat[k].count()

# %%
total_topics_each_user = pd.DataFrame(total_no_topics, columns=['TotalNoOfTopicsCovered'])

# %%
total_topics_each_user['TotalNoOfTopicsLeft'] = user1_mat[k].isnull().sum()

# %%
total_topics_each_user.head()
# Out:
#                               TotalNoOfTopicsCovered  TotalNoOfTopicsLeft
# uid
# 0bCevN2VYjP8xtFOWzL2PhSrRhF3                      59                 1282
# 0BqUU9G19RT1nWbqDVrftCzMNSz2                      90                 1251
# 0Di4XsfDVOZThME82IbBie1qhGy2                     193                 1148
# 0HUp1SizlSXHXA4v1JJ8PtuJcOH2                      24                 1317
# 0MFCkxsXuXRPX9LeCG5N8vl6u0L2                      64                 1277

# %%
total_topics_each_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8424 entries, 0bCevN2VYjP8xtFOWzL2PhSrRhF3 to sTwBypTiEUQDIubpzwbVEbgCXN33
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TotalNoOfTopicsCovered  8424 non-null   int64
#  1   TotalNoOfTopicsLeft     8424 non-null   int64
# dtypes: int64(2)
# memory usage: 197.4+ KB

# %% [markdown]
# .

# %% [markdown]
# .
# .
# .

# %% [markdown]
# The time spent by spent by every user for each single topicname is..........

# %%
a = '0HUp1SizlSXHXA4v1JJ8PtuJcOH2'

# %%
user1_mat[a].dropna().sort_values(ascending=False)
# Out:
# topicNames
# Local News                              35.0
# Politics,Business,Technology            27.0
# Local News,Happy news                   25.0
# Global health,Europe                    16.0
# Asia,Climate Crisis,Science             16.0
# North America,Local News                16.0
# Politics,Human Rights                   13.0
# Africa,Human Rights                     10.0
# Global health                            8.0
# Europe,Local News                        7.0
# Start-ups,Technology                     4.0
# Business,Europe,Local News               4.0
# Business,North America,Human Stories     4.0
# Climate Crisis                           4.0
# Habitat,Asia,Climate Crisis              4.0
# Politics,Middle East,Finance             2.0
# Travel,Local News                        2.0
# Habitat,Africa,Climate Crisis            2.0
# Asia,Social Movements,Local News         2.0
# Coronavirus,Europe,Travel                1.0
# Sports,Happy news,Human Stories          1.0
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# And the top most 5 important topics are...........

# %%
user1_mat[a].dropna().sort_values(ascending=False)[:5]
# Out:
# topicNames
# Local News                      35.0
# Politics,Business,Technology    27.0
# Local News,Happy news           25.0
# Global health,Europe            16.0
# Asia,Climate Crisis,Science     16.0
# Name: 0HUp1SizlSXHXA4v1JJ8PtuJcOH2, dtype: float64

# %%
user2.head()
# Out:
#    newsID                           uid  watchTimeInSeconds  \
# 0      12                           NaN                   3
# 1      12  0bCevN2VYjP8xtFOWzL2PhSrRhF3                   1
# 2      12  0BqUU9G19RT1nWbqDVrftCzMNSz2                   2
# 3      12  0Di4XsfDVOZThME82IbBie1qhGy2                   2
# 4      12  0HUp1SizlSXHXA4v1JJ8PtuJcOH2                   1
#
#                                                title             keywords  \
# 0  Spain will reopen borders to EU states on June...  border,spain,travel
# 1  Spain will reopen borders to EU states on June...  border,spain,travel
# 2  Spain will reopen borders to EU states on June...  border,spain,travel
# 3  Spain will reopen borders to EU states on June...  border,spain,travel
# 4  Spain will reopen borders to EU states on June...  border,spain,travel
#
#                                              summary          publishedOn  \
# 0  During his weekly video conference with Spain’...  2020-06-15 05:29:12
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# The keywords that mostly used......

# %%
keywords = article[['id','title','keywords','publishedOn']].copy()

# %%
keywords = keywords.dropna()

# %%
keywords.head()
# Out:
#    id                                              title  \
# 0  12  Spain will reopen borders to EU states on June...
# 1  13  Spanish judge shelves case against Women’s Day...
# 2  14  Spain edges closer to ‘new normality’ with fin...
# 5  17  Spain issues new guidelines for safe return to...
# 6  18  Scandal over COVID-19 deaths at Madrid nursing...
#
#                                            keywords          publishedOn
# 0                               border,spain,travel  2020-06-15 05:29:12
# 1                women's day,spanish judge,covid-19  2020-06-15 08:53:15
# 2                     final phase,coronavirus,SPAIN  2020-06-15 09:01:40
# 5                 education,school,primary students  2020-06-15 05:11:20
# 6  Madrid nursing homes,Covid-19 pandemic,political  2020-06-15 05:00:24

# %% [markdown]
# lets merge the two tables to create a new table which links users and the keywords they have used.

# %%
news_read_main.head(2)
# Out:
#    newsID                           uid  watchTimeInSeconds
# 0       1  2EHvElPRM3MckdZaMRP3a2fMLfi2                   3
# 1       1  luNCbENhOUNXUE8FYi3ejFxQSNK2                   1

# %%
keywords = keywords.rename({'id':'newsID'},axis=1)

# %%
keys = pd.merge(keywords,news_read_main)
keys = keys.dropna()

# %%
keys.head()
# Out:
#    newsID                                              title  \
# 1      12  Spain will reopen borders to EU states on June...
# 2      12  Spain will reopen borders to EU states on June...
# 3      12  Spain will reopen borders to EU states on June...
# 4      12  Spain will reopen borders to EU states on June...
# 5      12  Spain will reopen borders to EU states on June...
#
#               keywords          publishedOn                           uid  \
# 1  border,spain,travel  2020-06-15 05:29:12  0bCevN2VYjP8xtFOWzL2PhSrRhF3
# 2  border,spain,travel  2020-06-15 05:29:12  0BqUU9G19RT1nWbqDVrftCzMNSz2
# 3  border,spain,travel  2020-06-15 05:29:12  0Di4XsfDVOZThME82IbBie1qhGy2
# 4  border,spain,travel  2020-06-15 05:29:12  0HUp1SizlSXHXA4v1JJ8PtuJcOH2
# 5  border,spain,travel  2020-06-15 05:29:12  0MFCkxsXuXRPX9LeCG5N8vl6u0L2
#
#    watchTimeInSeconds
# 1                   1
# 2                   2
# 3                   2
# 4                   1
# 5                   1

# %%
keys.publishedOn = pd.to_datetime(keys.publishedOn, format='%Y-%m-%d')

# %%
keys.publishedOn = keys.publishedOn.dt.strftime('%Y-%m-%d')

# %%
keys.head()
# Out:
#    newsID                                              title  \
# 1      12  Spain will reopen borders to EU states on June...
# 2      12  Spain will reopen borders to EU states on June...
# 3      12  Spain will reopen borders to EU states on June...
# 4      12  Spain will reopen borders to EU states on June...
# 5      12  Spain will reopen borders to EU states on June...
#
#               keywords publishedOn                           uid  \
# 1  border,spain,travel  2020-06-15  0bCevN2VYjP8xtFOWzL2PhSrRhF3
# 2  border,spain,travel  2020-06-15  0BqUU9G19RT1nWbqDVrftCzMNSz2
# 3  border,spain,travel  2020-06-15  0Di4XsfDVOZThME82IbBie1qhGy2
# 4  border,spain,travel  2020-06-15  0HUp1SizlSXHXA4v1JJ8PtuJcOH2
# 5  border,spain,travel  2020-06-15  0MFCkxsXuXRPX9LeCG5N8vl6u0L2
#
#    watchTimeInSeconds
# 1                   1
# 2                   2
# 3                   2
# 4                   1
# 5                   1

# %% [markdown]
# The keywords every user used on each and every day.............

# %%
keywords_allusers = pd.DataFrame(keys.groupby(['uid','publishedOn','watchTimeInSeconds']).keywords.first())

# %%
keywords_allusers.head()
# Out:
#                                                                                        keywords
# uid                          publishedOn watchTimeInSeconds
# 0BqUU9G19RT1nWbqDVrftCzMNSz2 2020-06-15  2                                  border,spain,travel
#                                          3                   women's day,spanish judge,covid-19
# 0Di4XsfDVOZThME82IbBie1qhGy2 2020-06-15  1                   women's day,spanish judge,covid-19
#                                          2                                  border,spain,travel
# 0HUp1SizlSXHXA4v1JJ8PtuJcOH2 2020-06-15  1                                  border,spain,travel

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# the content style id's that users used are......

# %%
content_style = article[['id','title','contentStyleID','publishedOn']].copy()

# %%
content_style = content_style.dropna()

# %%
content_style.head()
# Out:
#           id                                              title  \
# 19229  20376                 Deep-Dive: Witchcraft and Dementia
# 19271  20422  Fact-check: Nearly half of people who catch CO...
# 19272  20423  Fact-check: Cigarette smoking declined in deve...
# 19287  20439  Quiz: Princess Diana: Controversial BBC Interview
# 19289  20441                                Quiz: It's All Good
#
#        contentStyleID          publishedOn
# 19229             8.0  2021-05-30 13:02:38
# 19271             6.0  2021-06-01 18:49:17
# 19272             6.0  2021-06-01 18:49:09
# 19287             7.0  2021-06-01 18:49:04
# 19289             7.0  2021-06-01 18:49:00

# %%
content_style = content_style.rename({'id':'newsID'},axis=1)

# %%
cs = pd.merge(content_style,news_read_main)
cs = cs.dropna()

# %%
cs.head()
# Out:
#    newsID                               title  contentStyleID  \
# 1   20376  Deep-Dive: Witchcraft and Dementia             8.0
# 2   20376  Deep-Dive: Witchcraft and Dementia             8.0
# 3   20376  Deep-Dive: Witchcraft and Dementia             8.0
# 4   20376  Deep-Dive: Witchcraft and Dementia             8.0
# 5   20376  Deep-Dive: Witchcraft and Dementia             8.0
#
#            publishedOn                           uid  watchTimeInSeconds
# 1  2021-05-30 13:02:38  0e3JTFaWBtcZuxgCu0T5FIDO20i1                   1
# 2  2021-05-30 13:02:38  0Ux6aSqVNSbpQ7wuVD18U5RbLw22                   4
# 3  2021-05-30 13:02:38  1fm3OxWL7ZUP94r5QtZCrMfoicl1                   0
# 4  2021-05-30 13:02:38  1OCasJtb6ucNqPlpXC5MJAvgSyb2                   8
# 5  2021-05-30 13:02:38  1XENQbrWzVS8UtEPmtKQ9MpBfAD2                   1

# %%
cs.groupby(['uid','publishedOn','watchTimeInSeconds']).contentStyleID.first()
# Out:
# uid                           publishedOn          watchTimeInSeconds
# 06ycFjZqJoZuAsJSXA1lzifDh5i1  2021-06-16 16:34:14  1                     5.0
# 0BqUU9G19RT1nWbqDVrftCzMNSz2  2021-06-05 14:49:48  1                     2.0
#                               2021-06-05 14:51:08  2                     1.0
#                               2021-06-05 14:52:29  1                     1.0
#                               2021-06-07 13:10:09  4                     8.0
#                                                                         ...
# zp2TifezHGaSbgJ3MR1Z6Otnq362  2021-06-17 03:07:24  0                     6.0
#                               2021-06-17 03:07:33  4                     6.0
# zqdkOFcULTRF4DaWUh1Z6enOKKT2  2021-06-29 03:32:58  5                     6.0
#                               2021-06-29 03:43:58  13                    8.0
# zwIgO9TUONPOe5Jhar3owfKPyMU2  2021-06-16 16:34:14  15                    5.0
# Name: contentStyleID, Length: 18790, dtype: float64

# %% [markdown]
# The content style id's for all the users for a particluar date

# %%
cs_for_allusers = pd.DataFrame(cs.groupby(['uid','publishedOn','watchTimeInSeconds']).contentStyleID.first())

# %%
cs_for_allusers.head()
# Out:
#                                                                      contentStyleID
# uid                          publishedOn         watchTimeInSeconds
# 06ycFjZqJoZuAsJSXA1lzifDh5i1 2021-06-16 16:34:14 1                              5.0
# 0BqUU9G19RT1nWbqDVrftCzMNSz2 2021-06-05 14:49:48 1                              2.0
#                              2021-06-05 14:51:08 2                              1.0
#                              2021-06-05 14:52:29 1                              1.0
#                              2021-06-07 13:10:09 4                              8.0
